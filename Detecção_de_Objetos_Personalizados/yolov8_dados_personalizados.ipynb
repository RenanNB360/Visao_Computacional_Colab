# %% [markdown]
# <a href="https://colab.research.google.com/github/RenanNB360/Visao_Computacional_Colab/blob/main/Detec%C3%A7%C3%A3o_de_Objetos_Personalizados/yolov8_dados_personalizados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Criação da Base de Dados Personalizado

# %% [markdown]
# ## Clonar o repositório da ferramenta

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 21.00 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
pwd
# Out:
# '/content'

# %%
cd OIDv4_ToolKit/
# Out:
# /content/OIDv4_ToolKit

# %%
pwd
# Out:
# '/content/OIDv4_ToolKit'

# %%
ls
# Out:
# classes.txt  images/  LICENSE  main.py  modules/  README.md  requirements.txt

# %%
cat requirements.txt
# Out:
# pandas
# numpy
# awscli
#
# urllib3
#
# tqdm
#
# opencv-python

# %% [markdown]
# ## Instalando as bibliotecas

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 50.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 41.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 15.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# ...

# %% [markdown]
# ## Fazendo o download das imagens

# %%
# !python main.py downloader --classes Bus Car Person --type_csv train --limit 500 --multiclasses 1
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Bus', 'Car', 'Person'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 36313 KB/s, 0 seconds passed
# ...

# %%
# !python main.py downloader --classes Bus Car Person --type_csv test --limit 100 --multiclasses 1
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Bus', 'Car', 'Person'] together.
#    [ERROR] | Missing the test-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...100%, 49 MB, 27372 KB/s, 1 seconds passed
# ...

# %% [markdown]
# ## Conversão dos arquivos de anotação

# %% [markdown]
# Colocando as classes no arquivo classes.txt

# %%
# !cat classes.txt
# Out:
# Apple
# Orange
# Light switch

# %%
# !echo -e 'Bus\nCar\nPerson' > classes.txt

# %% [markdown]
# converter_annotations.py e adiciona-lo ao dirétorio

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pwd
# Out:
# '/content/OIDv4_ToolKit'

# %%
# !cp /content/gdrive/MyDrive/Projects\ Computing\ Vision/Deteccao_objetos_YOLOv8/arquivos/converter_annotations.py ./
# !cp /content/gdrive/MyDrive/Projects\ Computing\ Vision/Deteccao_objetos_YOLOv8/arquivos/gerar_test.py ./
# !cp /content/gdrive/MyDrive/Projects\ Computing\ Vision/Deteccao_objetos_YOLOv8/arquivos/gerar_train.py ./

# %%
ls
# Out:
# classes.txt               gerar_train.py  main.py   README.md
# converter_annotations.py  images/         modules/  requirements.txt
# gerar_test.py             LICENSE         OID/

# %% [markdown]
# Executar o arquivo de conversão

# %%
# !python converter_annotations.py
# Out:
# Subdiretorio atual: test
# Convertendo os annotations para a classe:  Bus_Car_Person
# 100% 291/291 [00:11<00:00, 24.65it/s]
# Subdiretorio atual: train
# Convertendo os annotations para a classe:  Bus_Car_Person
# 100% 1474/1474 [01:34<00:00, 15.61it/s]

# %% [markdown]
# ## Compactar o dataset

# %% [markdown]
# Base de treino

# %%
cd OID/Dataset/train/
# Out:
# /content/OIDv4_ToolKit/OID/Dataset/train

# %%
ls
# Out:
# Bus_Car_Person/

# %%
# !mv Bus_Car_Person/ obj/

# %%
ls
# Out:
# obj/

# %%
# !zip -r ../../../obj.zip obj -x obj/Label/*
# Out:
#   adding: obj/ (stored 0%)
#   adding: obj/aecd7416f432a683.jpg (deflated 0%)
#   adding: obj/21ff0b4d976a719b.jpg (deflated 0%)
#   adding: obj/834726108ca95d08.txt (deflated 52%)
#   adding: obj/9615140432e383a4.jpg (deflated 0%)
#   adding: obj/5f618d1c3ff0502c.jpg (deflated 0%)
#   adding: obj/85b58c619d8a11d5.txt (deflated 59%)
#   adding: obj/235474bb8695c2ad.jpg (deflated 1%)
#   adding: obj/c0aae06be56d33ce.jpg (deflated 1%)
#   adding: obj/0ba585aa33f0d695.jpg (deflated 0%)
#   adding: obj/e0693ff58ab9f5b2.txt (deflated 50%)
#   adding: obj/a359db740cb5b61e.jpg (deflated 0%)
#   adding: obj/9377479e88536761.jpg (deflated 0%)
#   adding: obj/6900d5915daafb4b.txt (deflated 27%)
#   adding: obj/520226aeb4a9598e.jpg (deflated 0%)
#   adding: obj/9accfb37917d13d5.jpg (deflated 0%)
#   adding: obj/71f26b1fa14c67f9.txt (deflated 34%)
#   adding: obj/7a3d849e6340e3f5.jpg (deflated 0%)
#   adding: obj/4a3a3df8352266d4.txt (deflated 35%)
# ...

# %%
cd ../../..
# Out:
# /content/OIDv4_ToolKit

# %%
# !cp ./obj.zip /content/gdrive/MyDrive/Projects\ Computing\ Vision/Deteccao_objetos_YOLOv8/arquivos/

# %% [markdown]
# Base de Teste

# %%
cd OID/Dataset/test/
# Out:
# /content/OIDv4_ToolKit/OID/Dataset/test

# %%
ls
# Out:
# Bus_Car_Person/

# %%
# !mv Bus_Car_Person/ valid

# %%
# !zip -r ../../../valid.zip valid -x valid/Label/*
# Out:
#   adding: valid/ (stored 0%)
#   adding: valid/8144049e153633c1.jpg (deflated 0%)
#   adding: valid/05f64242984ff159.txt (deflated 14%)
#   adding: valid/4614405aa41f8bb6.txt (deflated 45%)
#   adding: valid/8e39415ca2f5f2b4.txt (deflated 43%)
#   adding: valid/f73a9e435f55146e.jpg (deflated 0%)
#   adding: valid/30ee8097adcbae53.txt (deflated 43%)
#   adding: valid/f3ab2e0acb12ac94.jpg (deflated 0%)
#   adding: valid/18bdee7348320cfc.txt (deflated 45%)
#   adding: valid/0486e1de3ebdae15.jpg (deflated 0%)
#   adding: valid/5491473d6b7b24aa.txt (deflated 37%)
#   adding: valid/922a9619f1a13442.jpg (deflated 0%)
#   adding: valid/c5d73ac341743aa4.txt (deflated 60%)
#   adding: valid/fb1445125e0cc71f.txt (deflated 44%)
#   adding: valid/df22690af20d30f3.jpg (deflated 0%)
#   adding: valid/dc40a5590c5e9d3d.jpg (deflated 0%)
#   adding: valid/19f45e9dbd02b333.txt (deflated 26%)
#   adding: valid/a78b1ce93b4b6300.jpg (deflated 0%)
#   adding: valid/a40af4fc7f90d000.jpg (deflated 0%)
# ...

# %%
cd ../../..
# Out:
# /content/OIDv4_ToolKit

# %%
ls
# Out:
# classes.txt               gerar_train.py  main.py   OID/              valid.zip
# converter_annotations.py  images/         modules/  README.md
# gerar_test.py             LICENSE         obj.zip   requirements.txt

# %%
# !cp ./valid.zip /content/gdrive/MyDrive/Projects\ Computing\ Vision/Deteccao_objetos_YOLOv8/arquivos/

# %% [markdown]
# # Treinamento do Modelo

# %% [markdown]
# Verificando a GPU

# %%
# !nvidia-smi
# Out:
# Fri Aug 25 20:09:51 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Preparação do dataset

# %%
cd ..
# Out:
# /

# %%
cd content/
# Out:
# /content

# %%
# !mkdir dataset

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/Projects\ Computing\ Vision/Deteccao_objetos_YOLOv8/arquivos/obj.zip ./

# %%
# !cp /content/gdrive/MyDrive/Projects\ Computing\ Vision/Deteccao_objetos_YOLOv8/arquivos/valid.zip ./

# %%
ls
# Out:
# dataset/  gdrive/  obj.zip  sample_data/  valid.zip

# %% [markdown]
# Dados de treino

# %%
# !unzip obj.zip -d dataset/
# Out:
# Archive:  obj.zip
#    creating: dataset/obj/
#   inflating: dataset/obj/aecd7416f432a683.jpg
#   inflating: dataset/obj/21ff0b4d976a719b.jpg
#   inflating: dataset/obj/834726108ca95d08.txt
#   inflating: dataset/obj/9615140432e383a4.jpg
#   inflating: dataset/obj/5f618d1c3ff0502c.jpg
#   inflating: dataset/obj/85b58c619d8a11d5.txt
#   inflating: dataset/obj/235474bb8695c2ad.jpg
#   inflating: dataset/obj/c0aae06be56d33ce.jpg
#   inflating: dataset/obj/0ba585aa33f0d695.jpg
#   inflating: dataset/obj/e0693ff58ab9f5b2.txt
#   inflating: dataset/obj/a359db740cb5b61e.jpg
#   inflating: dataset/obj/9377479e88536761.jpg
#   inflating: dataset/obj/6900d5915daafb4b.txt
#   inflating: dataset/obj/520226aeb4a9598e.jpg
#   inflating: dataset/obj/9accfb37917d13d5.jpg
#   inflating: dataset/obj/71f26b1fa14c67f9.txt
#   inflating: dataset/obj/7a3d849e6340e3f5.jpg
#   inflating: dataset/obj/4a3a3df8352266d4.txt
#   inflating: dataset/obj/3ca15aa07c470c8e.txt
# ...

# %%
# !mv dataset/obj dataset/train

# %% [markdown]
# Dados de teste

# %%
# !unzip valid.zip -d dataset/
# Out:
# Archive:  valid.zip
#    creating: dataset/valid/
#   inflating: dataset/valid/8144049e153633c1.jpg
#   inflating: dataset/valid/05f64242984ff159.txt
#   inflating: dataset/valid/4614405aa41f8bb6.txt
#   inflating: dataset/valid/8e39415ca2f5f2b4.txt
#   inflating: dataset/valid/f73a9e435f55146e.jpg
#   inflating: dataset/valid/30ee8097adcbae53.txt
#   inflating: dataset/valid/f3ab2e0acb12ac94.jpg
#   inflating: dataset/valid/18bdee7348320cfc.txt
#   inflating: dataset/valid/0486e1de3ebdae15.jpg
#   inflating: dataset/valid/5491473d6b7b24aa.txt
#   inflating: dataset/valid/922a9619f1a13442.jpg
#   inflating: dataset/valid/c5d73ac341743aa4.txt
#   inflating: dataset/valid/fb1445125e0cc71f.txt
#   inflating: dataset/valid/df22690af20d30f3.jpg
#   inflating: dataset/valid/dc40a5590c5e9d3d.jpg
#   inflating: dataset/valid/19f45e9dbd02b333.txt
#   inflating: dataset/valid/a78b1ce93b4b6300.jpg
#   inflating: dataset/valid/a40af4fc7f90d000.jpg
# ...

# %% [markdown]
# ## Instalação do YOLOv8 e importações

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.5/609.5 kB 6.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Configurações do arquivo YAML

# %%
# !touch configs_modelo.yaml

# %%
# %%writefile configs_modelo.yaml
# path: '/content/dataset/'
# train: 'train/'
# val: 'valid/'
# test: #opcional
#
# nc: 3
# names: ['Bus','Car','Person']
# Out:
# Overwriting configs_modelo.yaml

# %% [markdown]
# # Treino do Modelo

# %%
diretorio_raiz = '/content/'
arquivo_config = os.path.join(diretorio_raiz, 'configs_modelo.yaml')

# %%
arquivo_config
# Out:
# '/content/configs_modelo.yaml'

# %%
# !yolo task=detect mode=train data={arquivo_config} epochs=10 # model=medium (padrão)
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 23.2MB/s]
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/content/runs/detect/train/weights/last.pt data={arquivo_config} epochs=10
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
dir_resultados = '/content/runs/detect/train2'

# %% [markdown]
# # Avaliação do Modelo

# %% [markdown]
# Verificando o mAP do modelo

# %%
# !yolo task=detect mode=val model={dir_resultados}/weights/best.pt name=yolo8m_modelo_eval data=configs_modelo.yaml
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients
# val: Scanning /content/dataset/valid.cache... 291 images, 0 backgrounds, 0 corrupt: 100% 291/291 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:10<00:00,  1.81it/s]
#                    all        291        643       0.65      0.569        0.6      0.438
#                    Bus        291        153      0.796      0.745      0.805      0.644
#                    Car        291        253      0.727      0.644      0.704      0.499
#                 Person        291        237      0.425      0.316      0.292      0.171
# Speed: 1.4ms preprocess, 7.1ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to runs/detect/yolo8m_modelo_eval

# %% [markdown]
# Gráficos

# %%
def mostrar(img):
  fig = plt.gcf()
  fig.set_size_inches(16, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
resultados_grafico = cv2.imread(os.path.join(dir_resultados, 'results.png'))
mostrar(resultados_grafico)

# %%
dir_resultado_val = '/content/runs/detect/yolo8m_modelo_eval'

# %%
imgs = ['F1_curve.png','PR_curve.png','P_curve.png','R_curve.png']
plt.figure(figsize=(18,14))
for i, img in enumerate(imgs):
  grafico = cv2.imread(os.path.join(dir_resultado_val, img))
  grafico = cv2.cvtColor(grafico, cv2.COLOR_BGR2RGB)
  plt.subplot(2, 2, i + 1)
  plt.title(imgs[i])
  plt.imshow(grafico)
  plt.axis('off')
plt.show()

# %%
matriz_confusao = cv2.imread(os.path.join(dir_resultado_val, 'confusion_matrix.png'))
mostrar(matriz_confusao)

# %% [markdown]
# # Testando o Modelo Treinado em Vídeo

# %%
# !mkdir arquivos_teste

# %%
# !yolo task=detect mode=predict model={dir_resultados}/weights/best.pt source='/content/gdrive/MyDrive/Projects Computing Vision/Deteccao_objetos_YOLOv8/arquivos/video_teste.mp4' save=True
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients
#
# video 1/1 (1/895) /content/gdrive/MyDrive/Projects Computing Vision/Deteccao_objetos_YOLOv8/arquivos/video_teste.mp4: 384x640 1 Bus, 2 Cars, 80.8ms
# video 1/1 (2/895) /content/gdrive/MyDrive/Projects Computing Vision/Deteccao_objetos_YOLOv8/arquivos/video_teste.mp4: 384x640 1 Bus, 2 Cars, 9.0ms
# video 1/1 (3/895) /content/gdrive/MyDrive/Projects Computing Vision/Deteccao_objetos_YOLOv8/arquivos/video_teste.mp4: 384x640 1 Bus, 1 Car, 8.0ms
# video 1/1 (4/895) /content/gdrive/MyDrive/Projects Computing Vision/Deteccao_objetos_YOLOv8/arquivos/video_teste.mp4: 384x640 2 Buss, 2 Cars, 8.1ms
# video 1/1 (5/895) /content/gdrive/MyDrive/Projects Computing Vision/Deteccao_objetos_YOLOv8/arquivos/video_teste.mp4: 384x640 1 Bus, 1 Car, 8.6ms
# ...

# %%
# !cp /content/runs/detect/predict/video_teste.avi arquivos_teste/

# %%
# !ffmpeg -y -loglevel panic -i /content/arquivos_teste/video_teste.avi result.mp4

# %%
def exibir_video(video_caminho):
  from IPython.display import HTML
  from base64 import b64encode
  mp4 = open(video_caminho, 'rb').read()
  data_url = 'data:video/mp4;base64,' + b64encode(mp4).decode()
  return HTML("""
  <video width=500 controls>
    <source src="%s" type="video/mp4"
  </video>
  """ % data_url)

# %%
path = '/content/result.mp4'

# %%
exibir_video(path)
# Out:
#   <video width=500 controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4"
#   </video>
